# %%
conda install -c conda-forge notebook pandas sqlalchemy snowflake-sqlalchemy
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - notebook
#     - pandas
#     - snowflake-sqlalchemy
#     - sqlalchemy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     asn1crypto-1.5.1           |     pyhd8ed1ab_1          84 KB  conda-forge
#     ca-certificates-2024.12.14 |       h8857fd0_0         153 KB  conda-forge
#     certifi-2024.12.14         |     pyhd8ed1ab_0         158 KB  conda-forge
#     conda-24.11.3              |  py312hb401068_0         1.1 MB  conda-forge
#     importlib_resources-6.5.2  |     pyhd8ed1ab_0          33 KB  conda-forge
#     jupyterlab-4.3.4           |     pyhd8ed1ab_0         6.9 MB  conda-forge
#     jupyterlab_server-2.27.3   |     pyhd8ed1ab_1          48 KB  conda-forge
#     libcxx-19.1.7              |       hf95d169_0         516 KB  conda-forge
#     notebook-7.3.2             |     pyhd8ed1ab_0         8.6 MB  conda-forge
#     openssl-3.4.0              |       hc426f3f_1         2.5 MB  conda-forge
#     pandas-2.2.3               |  py312h98e817e_1        13.9 MB  conda-forge
#     snowflake-connector-python-3.12.4|  py312hec45ffd_0         1.1 MB  conda-forge
#     snowflake-sqlalchemy-1.7.3 |     pyhd8ed1ab_0          56 KB  conda-forge
#     sqlalchemy-2.0.37          |  py312h01d7ebd_0         3.3 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        38.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   asn1crypto         conda-forge/noarch::asn1crypto-1.5.1-pyhd8ed1ab_1
#   importlib_resourc~ conda-forge/noarch::importlib_resources-6.5.2-pyhd8ed1ab_0
#   snowflake-connect~ conda-forge/osx-64::snowflake-connector-python-3.12.4-py312hec45ffd_0
#   snowflake-sqlalch~ conda-forge/noarch::snowflake-sqlalchemy-1.7.3-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2024.8.30-h8857fd0_0 --> 2024.12.14-h8857fd0_0
#   certifi                            2024.8.30-pyhd8ed1ab_0 --> 2024.12.14-pyhd8ed1ab_0
#   conda                              24.9.2-py312hb401068_0 --> 24.11.3-py312hb401068_0
#   jupyterlab         pkgs/main/osx-64::jupyterlab-4.0.11-p~ --> conda-forge/noarch::jupyterlab-4.3.4-pyhd8ed1ab_0
#   jupyterlab_server  pkgs/main/osx-64::jupyterlab_server-2~ --> conda-forge/noarch::jupyterlab_server-2.27.3-pyhd8ed1ab_1
#   libcxx                pkgs/main::libcxx-14.0.6-h9765a3e_0 --> conda-forge::libcxx-19.1.7-hf95d169_0
#   notebook           pkgs/main/osx-64::notebook-7.0.8-py31~ --> conda-forge/noarch::notebook-7.3.2-pyhd8ed1ab_0
#   openssl                                  3.3.2-hd23fc13_0 --> 3.4.0-hc426f3f_1
#   pandas             pkgs/main::pandas-2.2.2-py312h77d3abe~ --> conda-forge::pandas-2.2.3-py312h98e817e_1
#   sqlalchemy         pkgs/main::sqlalchemy-2.0.30-py312h46~ --> conda-forge::sqlalchemy-2.0.37-py312h01d7ebd_0
#
#
#
# Downloading and Extracting Packages:
# pandas-2.2.3         | 13.9 MB   |                                       |   0%
# notebook-7.3.2       | 8.6 MB    |                                       |   0%
#
# jupyterlab-4.3.4     | 6.9 MB    |                                       |   0%
#
#
# sqlalchemy-2.0.37    | 3.3 MB    |                                       |   0%
#
#
#
# openssl-3.4.0        | 2.5 MB    |                                       |   0%
#
#
#
#
# conda-24.11.3        | 1.1 MB    |                                       |   0%
#
#
#
#
#
# snowflake-connector- | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
# libcxx-19.1.7        | 516 KB    |                                       |   0%
#
#
#
#
#
#
#
# certifi-2024.12.14   | 158 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 153 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# asn1crypto-1.5.1     | 84 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# snowflake-sqlalchemy | 56 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# jupyterlab_server-2. | 48 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# importlib_resources- | 33 KB     |                                       |   0%
#
# jupyterlab-4.3.4     | 6.9 MB    |                                       |   0%
#
#
#
# pandas-2.2.3         | 13.9 MB   |                                       |   0%
#
#
# sqlalchemy-2.0.37    | 3.3 MB    | 1                                     |   0%
# notebook-7.3.2       | 8.6 MB    |                                       |   0%
#
# jupyterlab-4.3.4     | 6.9 MB    | #                                     |   3%
#
#
#
# pandas-2.2.3         | 13.9 MB   | 4                                     |   1%
#
#
# sqlalchemy-2.0.37    | 3.3 MB    | #5                                    |   4%
# notebook-7.3.2       | 8.6 MB    | 5                                     |   1%
#
# pandas-2.2.3         | 13.9 MB   | 7                                     |   2%
# notebook-7.3.2       | 8.6 MB    | #                                     |   3%
#
#
#
# openssl-3.4.0        | 2.5 MB    | ####4                                 |  12%
#
#
# sqlalchemy-2.0.37    | 3.3 MB    | ##6                                   |   7%
#
# pandas-2.2.3         | 13.9 MB   | #                                     |   3%
#
#
#
# openssl-3.4.0        | 2.5 MB    | #####6                                |  15%
# pandas-2.2.3         | 13.9 MB   | #3                                    |   4%
#
# jupyterlab-4.3.4     | 6.9 MB    | ######5                               |  18%
#
#
#
# openssl-3.4.0        | 2.5 MB    | ######7                               |  18%
# notebook-7.3.2       | 8.6 MB    | ##8                                   |   8%
#
#
# pandas-2.2.3         | 13.9 MB   | ##                                    |   6%
#
#
# sqlalchemy-2.0.37    | 3.3 MB    | #########5                            |  26%
#
#
#
# openssl-3.4.0        | 2.5 MB    | ###########2                          |  30%
#
# jupyterlab-4.3.4     | 6.9 MB    | #######6                              |  21%
# pandas-2.2.3         | 13.9 MB   | ##6                                   |   7%
#
#
#
# openssl-3.4.0        | 2.5 MB    | ###############9                      |  43%
#
# jupyterlab-4.3.4     | 6.9 MB    | #########6                            |  26%
#
#
# sqlalchemy-2.0.37    | 3.3 MB    | ############2                         |  33%
# notebook-7.3.2       | 8.6 MB    | ####8                                 |  13%
#
#
#
# openssl-3.4.0        | 2.5 MB    | ##################4                   |  50%
# pandas-2.2.3         | 13.9 MB   | ###                                   |   8%
#
# jupyterlab-4.3.4     | 6.9 MB    | ##########8                           |  29%
#
#
# sqlalchemy-2.0.37    | 3.3 MB    | ##############4                       |  39%
# notebook-7.3.2       | 8.6 MB    | ######4                               |  17%
#
#
#
# openssl-3.4.0        | 2.5 MB    | #####################                 |  57%
#
#
# sqlalchemy-2.0.37    | 3.3 MB    | ################5                     |  45%
#
# pandas-2.2.3         | 13.9 MB   | ###3                                  |   9%
#
#
#
# openssl-3.4.0        | 2.5 MB    | #######################4              |  63%
# notebook-7.3.2       | 8.6 MB    | #######2                              |  20%
#
#
# sqlalchemy-2.0.37    | 3.3 MB    | ##################4                   |  50%
#
# jupyterlab-4.3.4     | 6.9 MB    | ############9                         |  35%
# pandas-2.2.3         | 13.9 MB   | ###6                                  |  10%
#
#
#
# openssl-3.4.0        | 2.5 MB    | #########################7            |  70%
#
#
# sqlalchemy-2.0.37    | 3.3 MB    | ####################4                 |  55%
# notebook-7.3.2       | 8.6 MB    | ########8                             |  24%
#
#
#
# openssl-3.4.0        | 2.5 MB    | ############################          |  76%
#
# pandas-2.2.3         | 13.9 MB   | ###9                                  |  11%
#
#
# sqlalchemy-2.0.37    | 3.3 MB    | ######################1               |  60%
# notebook-7.3.2       | 8.6 MB    | #########5                            |  26%
#
#
#
# openssl-3.4.0        | 2.5 MB    | ##############################1       |  82%
#
# jupyterlab-4.3.4     | 6.9 MB    | ##############7                       |  40%
#
#
# pandas-2.2.3         | 13.9 MB   | ####2                                 |  12%
# notebook-7.3.2       | 8.6 MB    | ##########3                           |  28%
#
#
#
# openssl-3.4.0        | 2.5 MB    | ################################5     |  88%
#
# pandas-2.2.3         | 13.9 MB   | ####5                                 |  12%
# notebook-7.3.2       | 8.6 MB    | ###########1                          |  30%
#
#
# sqlalchemy-2.0.37    | 3.3 MB    | #########################8            |  70%
#
#
#
# openssl-3.4.0        | 2.5 MB    | ##################################6   |  94%
#
# pandas-2.2.3         | 13.9 MB   | ####8                                 |  13%
# notebook-7.3.2       | 8.6 MB    | ###########8                          |  32%
#
#
#
# openssl-3.4.0        | 2.5 MB    | ####################################7 |  99%
#
#
# sqlalchemy-2.0.37    | 3.3 MB    | ###########################3          |  74%
#
# pandas-2.2.3         | 13.9 MB   | #####1                                |  14%
# notebook-7.3.2       | 8.6 MB    | ############7                         |  34%
#
#
# sqlalchemy-2.0.37    | 3.3 MB    | #############################1        |  79%
#
# jupyterlab-4.3.4     | 6.9 MB    | #################9                    |  49%
#
#
#
#
# conda-24.11.3        | 1.1 MB    | 5                                     |   1%
#
#
#
# pandas-2.2.3         | 13.9 MB   | #####5                                |  15%
# notebook-7.3.2       | 8.6 MB    | #############5                        |  37%
#
#
#
#
# conda-24.11.3        | 1.1 MB    | #####1                                |  14%
#
# jupyterlab-4.3.4     | 6.9 MB    | ##################7                   |  51%
#
#
# pandas-2.2.3         | 13.9 MB   | #####9                                |  16%
# notebook-7.3.2       | 8.6 MB    | ##############3                       |  39%
#
#
#
#
# conda-24.11.3        | 1.1 MB    | #########8                            |  27%
#
# jupyterlab-4.3.4     | 6.9 MB    | ###################6                  |  53%
#
#
# pandas-2.2.3         | 13.9 MB   | ######2                               |  17%
# notebook-7.3.2       | 8.6 MB    | ###############1                      |  41%
#
#
#
#
# conda-24.11.3        | 1.1 MB    | #############9                        |  38%
#
# jupyterlab-4.3.4     | 6.9 MB    | ####################4                 |  55%
#
#
# pandas-2.2.3         | 13.9 MB   | ######5                               |  18%
# notebook-7.3.2       | 8.6 MB    | ###############8                      |  43%
#
#
#
#
# conda-24.11.3        | 1.1 MB    | ##################5                   |  50%
#
#
# sqlalchemy-2.0.37    | 3.3 MB    | ###################################   |  95%
#
# jupyterlab-4.3.4     | 6.9 MB    | #####################2                |  58%
# pandas-2.2.3         | 13.9 MB   | ######9                               |  19%
#
#
#
#
# conda-24.11.3        | 1.1 MB    | #######################7              |  64%
#
#
# sqlalchemy-2.0.37    | 3.3 MB    | ####################################4 |  99%
#
# jupyterlab-4.3.4     | 6.9 MB    | ######################                |  60%
# pandas-2.2.3         | 13.9 MB   | #######1                              |  19%
#
#
#
#
# conda-24.11.3        | 1.1 MB    | ############################9         |  78%
#
# pandas-2.2.3         | 13.9 MB   | #######5                              |  20%
# notebook-7.3.2       | 8.6 MB    | ##################2                   |  49%
#
#
#
#
# conda-24.11.3        | 1.1 MB    | ###################################1  |  95%
#
# pandas-2.2.3         | 13.9 MB   | #######9                              |  22%
# notebook-7.3.2       | 8.6 MB    | ###################1                  |  52%
#
#
#
#
#
#
# libcxx-19.1.7        | 516 KB    | #1                                    |   3%
#
# jupyterlab-4.3.4     | 6.9 MB    | ########################8             |  67%
# pandas-2.2.3         | 13.9 MB   | ########5                             |  23%
#
#
#
#
#
# snowflake-connector- | 1.1 MB    | 5                                     |   1%
#
#
#
#
#
#
# libcxx-19.1.7        | 516 KB    | ############6                         |  34%
#
# pandas-2.2.3         | 13.9 MB   | #########                             |  24%
#
#
#
#
#
# snowflake-connector- | 1.1 MB    | ###7                                  |  10%
#
#
# sqlalchemy-2.0.37    | 3.3 MB    | ##################################### | 100%
# notebook-7.3.2       | 8.6 MB    | ####################7                 |  56%
#
#
#
#
#
#
# libcxx-19.1.7        | 516 KB    | ########################1             |  65%
#
#
#
#
# conda-24.11.3        | 1.1 MB    | ##################################### | 100%
#
# pandas-2.2.3         | 13.9 MB   | #########4                            |  26%
#
#
#
#
#
# snowflake-connector- | 1.1 MB    | #######                               |  19%
# notebook-7.3.2       | 8.6 MB    | #####################4                |  58%
#
#
#
#
#
#
# libcxx-19.1.7        | 516 KB    | ###################################5  |  96%
#
#
#
#
#
#
# libcxx-19.1.7        | 516 KB    | ##################################### | 100%
#
# pandas-2.2.3         | 13.9 MB   | #########8                            |  27%
#
#
#
#
#
# snowflake-connector- | 1.1 MB    | ##########7                           |  29%
# notebook-7.3.2       | 8.6 MB    | ######################2               |  60%
#
#
#
#
#
#
#
# certifi-2024.12.14   | 158 KB    | ###7                                  |  10%
#
# jupyterlab-4.3.4     | 6.9 MB    | ############################1         |  76%
#
#
#
#
#
# pandas-2.2.3         | 13.9 MB   | ##########3                           |  28%
#
#
#
#
#
#
#
# certifi-2024.12.14   | 158 KB    | ##################7                   |  51%
#
#
#
#
#
#
#
# certifi-2024.12.14   | 158 KB    | ##############################        |  81%
# notebook-7.3.2       | 8.6 MB    | ######################9               |  62%
#
#
#
#
#
#
#
# certifi-2024.12.14   | 158 KB    | ##################################### | 100%
#
# jupyterlab-4.3.4     | 6.9 MB    | ############################8         |  78%
#
#
#
#
#
# pandas-2.2.3         | 13.9 MB   | ##########6                           |  29%
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 153 KB    | ###8                                  |  10%
#
#
#
#
#
# snowflake-connector- | 1.1 MB    | ##################8                   |  51%
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 153 KB    | #######7                              |  21%
#
# jupyterlab-4.3.4     | 6.9 MB    | #############################5        |  80%
# pandas-2.2.3         | 13.9 MB   | ###########                           |  30%
#
#
#
#
#
# snowflake-connector- | 1.1 MB    | #####################                 |  57%
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 153 KB    | ##################################7   |  94%
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 153 KB    | ##################################### | 100%
#
# jupyterlab-4.3.4     | 6.9 MB    | ##############################        |  81%
#
#
#
#
#
# snowflake-connector- | 1.1 MB    | #######################1              |  63%
# pandas-2.2.3         | 13.9 MB   | ###########2                          |  30%
#
# jupyterlab-4.3.4     | 6.9 MB    | ##############################6       |  83%
#
#
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.9 MB   | ###########4                          |  31%
#
#
#
#
#
# snowflake-connector- | 1.1 MB    | ########################8             |  67%
# notebook-7.3.2       | 8.6 MB    | ########################4             |  66%
#
#
#
#
#
#
#
#
#
# asn1crypto-1.5.1     | 84 KB     | ##################################### | 100%
#
# pandas-2.2.3         | 13.9 MB   | ############                          |  33%
# notebook-7.3.2       | 8.6 MB    | #########################4            |  69%
#
#
#
#
#
# snowflake-connector- | 1.1 MB    | ##############################7       |  83%
#
#
#
#
#
#
#
#
#
#
# snowflake-sqlalchemy | 56 KB     | ##########6                           |  29%
#
# jupyterlab-4.3.4     | 6.9 MB    | ################################4     |  88%
#
#
#
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.9 MB   | ############5                         |  34%
# notebook-7.3.2       | 8.6 MB    | ##########################2           |  71%
#
#
#
#
#
# snowflake-connector- | 1.1 MB    | ###################################   |  95%
#
#
#
#
#
#
#
#
#
#
#
# jupyterlab_server-2. | 48 KB     | ############2                         |  33%
#
# pandas-2.2.3         | 13.9 MB   | ############9                         |  35%
#
#
#
#
#
#
#
#
#
#
#
# jupyterlab_server-2. | 48 KB     | ##################################### | 100%
# notebook-7.3.2       | 8.6 MB    | ###########################           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
# importlib_resources- | 33 KB     | #################9                    |  49%
#
# jupyterlab-4.3.4     | 6.9 MB    | ##################################6   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.9 MB   | #############5                        |  37%
# notebook-7.3.2       | 8.6 MB    | ############################          |  76%
#
# pandas-2.2.3         | 13.9 MB   | ##############1                       |  38%
#
#
#
#
#
# snowflake-connector- | 1.1 MB    | ##################################### | 100%
# pandas-2.2.3         | 13.9 MB   | ##############7                       |  40%
# pandas-2.2.3         | 13.9 MB   | ###############5                      |  42%
# pandas-2.2.3         | 13.9 MB   | ################4                     |  44%
# pandas-2.2.3         | 13.9 MB   | #################3                    |  47%
# pandas-2.2.3         | 13.9 MB   | ##################3                   |  50%
# pandas-2.2.3         | 13.9 MB   | ###################3                  |  52%
#
# jupyterlab-4.3.4     | 6.9 MB    | ##################################### | 100%
#
# pandas-2.2.3         | 13.9 MB   | #########################7            |  70%
# notebook-7.3.2       | 8.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from snowflake.sqlalchemy import URL
from sqlalchemy import create_engine
import pandas as pd
import uuid

import os

user = os.environ.get('SNOWFLAKE_USER')
password = os.environ.get('SNOWFLAKE_PASS')
account = os.environ.get('SNOWFLAKE_ACCOUNT')

# %%
if not all([user, password, account]):
    print("Missing environment variables. Please check Snowflake Connection setup.")
else:
    from sqlalchemy import create_engine
    from snowflake.sqlalchemy import URL

    engine = create_engine(URL(
        account = account,
        user = user,
        password = password,
        database = 'SF_LEADMANAGEMENT',
        schema = 'PUBLIC',
        warehouse = 'COMPUTE_WH',
        role='ACCOUNTADMIN'
    ))

    connection = engine.connect()

# %%
# Read data from CompanyLeads
query = "SELECT * FROM CompanyLeads;"
df_leads = pd.read_sql(query, connection)

print(df_leads.head())
# Out:
#                                      id  state      createddateutc  \
# 0  d73c7d93-bc0b-c284-8786-08db8cec307b      3 2023-07-25 08:50:26
# 1  f4a6f637-b7e9-c4de-8339-08db8cef5067      2 2023-07-25 09:12:48
# 2  4633aa15-3c41-cc94-9176-08db8d0f3c4b      1 2023-07-25 13:01:18
# 3  57e80bf5-492d-cf3e-a516-08db8d179419      2 2023-07-25 14:01:01
# 4  1a527929-d64c-c031-104d-08db8d27c11a      2 2023-07-25 15:56:49
#
#   cancellationrequestdateutc cancellationdateutc cancellationrejectiondateutc  \
# 0        2023-07-31 12:21:42                 NaT          2023-08-01 10:25:30
# 1        2023-07-31 13:56:10 2023-08-01 10:24:21                          NaT
# 2        2023-08-01 10:19:09                 NaT                          NaT
# 3        2023-08-01 06:51:10 2023-08-01 10:23:46                          NaT
# 4        2023-08-01 07:11:25 2023-08-01 10:24:38                          NaT
#
#          soldemployee cancelledemployee      updateddateutc
# 0  xyz@pflegehilfe.de              None 2023-08-01 10:25:30
# 1  hij@pflegehilfe.de              None 2023-08-01 10:24:21
# 2  efg@pflegehilfe.de              None 2023-08-01 10:19:09
# 3  hij@pflegehilfe.de              None 2023-08-01 10:23:46
# 4  hij@pflegehilfe.de              None 2023-08-01 10:24:38

# %%
def transform_data(df):
    events = []
    for index, row in df.iterrows():
        # Event when lead is sold, State = 0
        if pd.notnull(row['createddateutc']):
            events.append({
                'id': str(uuid.uuid4()),
                'eventtype': 'LeadSold',
                'eventemployee': row['soldemployee'],
                'eventdate': row['createddateutc'],
                'leadid': row['id'],
                'updateddateutc': row['updateddateutc']
            })

        # Event when cancellation is requested, State = 1
        if pd.notnull(row['cancellationrequestdateutc']):
            events.append({
                'id': str(uuid.uuid4()),
                'eventtype': 'LeadRequestedCancellation',
                'eventemployee': 'Unknown',  # As specified in pdf use "Unknown" for these events
                'eventdate': row['cancellationrequestdateutc'],
                'leadid': row['id'],
                'updateddateutc': row['updateddateutc']
            })

        # Event when lead is cancelled, State = 2
        if pd.notnull(row['cancellationdateutc']):
            events.append({
                'id': str(uuid.uuid4()),
                'eventtype': 'LeadCancelled',
                'eventemployee': row['cancelledemployee'],
                'eventdate': row['cancellationdateutc'],
                'leadid': row['id'],
                'updateddateutc': row['updateddateutc']
            })

        # Event when cancellation is rejected, State = 3
        if pd.notnull(row['cancellationrejectiondateutc']):
            events.append({
                'id': str(uuid.uuid4()),
                'eventtype': 'LeadCancellationRejected',
                'eventemployee': 'Unknown',  # As specified, use "Unknown" for these events
                'eventdate': row['cancellationrejectiondateutc'],
                'leadid': row['id'],
                'updateddateutc': row['updateddateutc']
            })

    return pd.DataFrame(events)

# %%
print(df_leads.columns)

df_events = transform_data(df_leads)
# Out:
# Index(['id', 'state', 'createddateutc', 'cancellationrequestdateutc',
#        'cancellationdateutc', 'cancellationrejectiondateutc', 'soldemployee',
#        'cancelledemployee', 'updateddateutc'],
#       dtype='object')

# %%
# Insert transformed data back to Snowflake
df_events.to_sql('leadevents', con=engine, index=False, if_exists='append')
print("Data loaded successfully.")
# Out:
# Data loaded successfully.

# %%
# Close connection
connection.close()
